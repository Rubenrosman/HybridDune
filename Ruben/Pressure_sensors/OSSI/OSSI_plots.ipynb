# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime, timedelta


import xarray as xr
import matplotlib.pyplot as plt
import sys
sys.path.append(r'C:\Users\ruro\OneDrive - Boskalis\Documents\python\OSSI')
from KNMI_readers import read_knmi_uurgeg


import puv

# %%
experimentFolder = r"C:\Users\ruro\OneDrive - Boskalis\Documents\python\01-Fieldwork\Pressure_sensors\OSSI\OSSI_02_data"    #Grand map
instrument = 'OSSI_02'

df1 = xr.open_dataset(os.path.join(experimentFolder, 'raw_netcdf', instrument + '.nc'))
df2 = xr.open_dataset(os.path.join(experimentFolder,'QC', instrument +'.nc'))
df3 = xr.open_dataset(os.path.join(experimentFolder,'tailored', instrument +'.nc'))
# Out:
# c:\Users\ruro\AppData\Local\Programs\Python\Python39\lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
df2.p.transpose().plot()

# %%
df3
# Out:
# <xarray.Dataset> Size: 840kB
# Dimensions:  (t: 318, f: 320)
# Coordinates:
#   * t        (t) datetime64[ns] 3kB 2024-09-25T12:41:00 ... 2024-09-27T20:32:...
#   * f        (f) float64 3kB 0.0 0.03125 0.0625 0.09375 ... 9.906 9.938 9.969
# Data variables: (12/13)
#     zi       float64 8B ...
#     zb       float64 8B ...
#     sf       float64 8B ...
#     name     <U7 28B ...
#     h        (t) float64 3kB ...
#     vy       (t, f) float64 814kB ...
#     ...       ...
#     Hm0      (t) float64 3kB ...
#     Tp       (t) float64 3kB ...
#     Tm01     (t) float64 3kB ...
#     Tm02     (t) float64 3kB ...
#     Tmm10    (t) float64 3kB ...
#     Tps      (t) float64 3kB ...
# Attributes: (12/16)
#     Conventions:               CF-1.6
#     name:                      OSSI_02
#     instrument:                OSSI_02
#     instrument type:           OSSI
#     instrument serial number:  18.09.00.08
#     epsg:                      28992
#     ...                        ...
# ...

# %%
df3.h.plot()

# %%
plt.scatter(df3.t, df3.Hm0, marker='.')
